# %%
# Data Transformation
# Version 1
# 1/26/25
# 23:00

# %%
# Importing Modules

# Importing SYS
import sys

# Importing OS
import os

# Add the root directory to sys.path
sys.path.append(os.path.abspath(".."))

# Now you can use absolute imports
from d497_helpers import folder_manager as fm, archive_module, checkpoint_helper as CheckPoint, database_helper as db_tool, config

# Pandas
import pandas as pd

# Numpy
import numpy as np

# %%
# function creates chunks of the data. 

def process_chunk(chunk):
    # List to store updated rows
    updated_rows = []

    # Group by state, year, and month
    grouped = chunk.groupby(['state_fipcode', 'year_code', 'month_code'])
    for (state, year, month), group in grouped:
        # Identify unspecified county
        unspecified = group[group['county_fipcode'] == 'C999']
        if unspecified.empty:
            # If no unspecified county, add the group as-is
            updated_rows.append(group)
            continue

        # Get total births from unspecified county
        unspecified_births = unspecified['births'].sum()

        # Filter counties that are not unspecified
        other_counties = group[group['county_fipcode'] != 'C999']
        num_counties = len(other_counties)

        if num_counties > 0:
            # Distribute births evenly
            per_county = unspecified_births // num_counties
            remainder = unspecified_births % num_counties

            # Add evenly distributed births
            other_counties = other_counties.copy()  # Avoid modifying a slice of DataFrame
            other_counties['births'] += per_county

            # Distribute remainder to random counties
            if remainder > 0:
                remainder_indices = np.random.choice(other_counties.index.to_numpy(), size=remainder, replace=False)
                other_counties.loc[remainder_indices, 'births'] += 1

        # Append updated rows (excluding unspecified counties)
        updated_rows.append(other_counties)

    # Combine updated rows back into a single DataFrame
    return pd.concat(updated_rows, ignore_index=True)

# %%
# Initilizing 
db_tool.initialize_engine()
db_tool.initialize_session()

# %%
# Process each chunk.

# The data will export the data the database's cdc data table. 
# For each chunk of data, unspecified county's data is split and distributed into the rest of the state's counties. 
# The chunk is then uploaded back into the database into a new table callled processed_cdc_data. 


for year in range(1995, 2024):
    for month in range(1, 13):

        query = f"SELECT * FROM cdc_data WHERE year_code = {year} AND month_code = {month}"
        # Read a chunk of data from the database

        chunk = pd.DataFrame()
        chunk = db_tool.export_df_from_sql(query, chunk)
        
        # Process the chunk
        
        updated_chunk = pd.DataFrame()
        updated_chunk = process_chunk(chunk); # Semi colon to suppress output
        
        # Save the processed chunk back to the database
        db_tool.append_to_sql(updated_chunk, "processed_cdc_data")

        del chunk
        del updated_chunk
# Out:
# 2025-02-01 00:02:48,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:48,824 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 1")
# 2025-02-01 00:02:48,825 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:48,827 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 1")
# 2025-02-01 00:02:48,828 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:48,829 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 1
# 2025-02-01 00:02:48,829 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:48,873 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:48,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:48,953 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:48,954 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:48,955 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("processed_cdc_data")
# 2025-02-01 00:02:48,956 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:48,957 INFO sqlalchemy.engine.Engine
# CREATE TABLE processed_cdc_data (
# 	year_code TEXT,
# 	month_code TEXT,
# 	state TEXT,
# 	state_code TEXT,
# 	state_fipcode TEXT,
# 	county TEXT,
# 	county_fipcode TEXT,
# 	fips_five TEXT,
# 	births BIGINT
# )
#
#
# 2025-02-01 00:02:48,958 INFO sqlalchemy.engine.Engine [no key 0.00110s] ()
# 2025-02-01 00:02:49,088 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:49,089 INFO sqlalchemy.engine.Engine [generated in 0.00285s] [('1995', '1', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 464), ('1995', '1', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '1', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 658), ('1995', '1', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '1', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 631), ('1995', '1', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '1', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 340), ('1995', '1', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 517)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '1', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 549), ('1995', '1', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 357)]
# 2025-02-01 00:02:49,143 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:49,327 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:49,329 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 2")
# 2025-02-01 00:02:49,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,331 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 2")
# 2025-02-01 00:02:49,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,332 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 2
# 2025-02-01 00:02:49,333 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,372 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:49,449 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:49,451 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:49,452 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,456 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:49,457 INFO sqlalchemy.engine.Engine [generated in 0.00273s] [('1995', '2', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 465), ('1995', '2', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '2', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 658), ('1995', '2', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '2', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '2', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '2', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 340), ('1995', '2', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 517)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '2', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 549), ('1995', '2', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:49,461 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:49,765 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:49,766 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 3")
# 2025-02-01 00:02:49,767 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,768 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 3")
# 2025-02-01 00:02:49,769 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,770 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 3
# 2025-02-01 00:02:49,771 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,813 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:49,891 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:49,893 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:49,894 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:49,900 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:49,901 INFO sqlalchemy.engine.Engine [generated in 0.00334s] [('1995', '3', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 464), ('1995', '3', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '3', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 658), ('1995', '3', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 846), ('1995', '3', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '3', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '3', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '3', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 518)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '3', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '3', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:49,904 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,091 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,093 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 4")
# 2025-02-01 00:02:50,093 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,094 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 4")
# 2025-02-01 00:02:50,095 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,096 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 4
# 2025-02-01 00:02:50,096 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,137 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,270 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,274 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:50,275 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,284 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:50,285 INFO sqlalchemy.engine.Engine [generated in 0.00573s] [('1995', '4', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 464), ('1995', '4', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1119), ('1995', '4', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 659), ('1995', '4', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '4', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '4', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '4', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '4', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 517)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '4', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '4', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 357)]
# 2025-02-01 00:02:50,288 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,534 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,535 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 5")
# 2025-02-01 00:02:50,536 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,537 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 5")
# 2025-02-01 00:02:50,538 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,539 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 5
# 2025-02-01 00:02:50,540 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,579 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,652 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,654 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:50,655 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,660 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:50,660 INFO sqlalchemy.engine.Engine [generated in 0.00284s] [('1995', '5', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 465), ('1995', '5', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '5', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 658), ('1995', '5', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '5', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 631), ('1995', '5', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '5', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '5', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 517)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '5', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1995', '5', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:50,664 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,847 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 6")
# 2025-02-01 00:02:50,847 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,848 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 6")
# 2025-02-01 00:02:50,849 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,850 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 6
# 2025-02-01 00:02:50,850 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,899 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:50,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:50,988 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:50,989 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:50,994 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:50,994 INFO sqlalchemy.engine.Engine [generated in 0.00272s] [('1995', '6', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 464), ('1995', '6', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1119), ('1995', '6', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 658), ('1995', '6', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '6', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 631), ('1995', '6', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '6', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '6', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '6', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '6', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 357)]
# 2025-02-01 00:02:50,998 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,180 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,181 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 7")
# 2025-02-01 00:02:51,182 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,183 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 7")
# 2025-02-01 00:02:51,183 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,184 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 7
# 2025-02-01 00:02:51,184 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,224 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,302 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,305 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:51,306 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,310 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:51,311 INFO sqlalchemy.engine.Engine [generated in 0.00283s] [('1995', '7', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 465), ('1995', '7', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '7', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '7', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '7', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '7', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '7', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '7', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '7', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1995', '7', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:51,314 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,497 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,498 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 8")
# 2025-02-01 00:02:51,499 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,500 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 8")
# 2025-02-01 00:02:51,500 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,501 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 8
# 2025-02-01 00:02:51,502 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,541 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,617 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:51,618 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,624 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:51,625 INFO sqlalchemy.engine.Engine [generated in 0.00379s] [('1995', '8', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 465), ('1995', '8', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '8', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '8', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '8', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '8', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '8', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '8', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '8', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '8', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 357)]
# 2025-02-01 00:02:51,629 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,811 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,812 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 9")
# 2025-02-01 00:02:51,812 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,813 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 9")
# 2025-02-01 00:02:51,814 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,814 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 9
# 2025-02-01 00:02:51,815 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,855 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:51,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:51,936 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:51,937 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:51,942 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:51,943 INFO sqlalchemy.engine.Engine [generated in 0.00297s] [('1995', '9', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 463), ('1995', '9', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '9', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '9', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '9', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '9', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '9', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '9', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '9', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '9', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:51,946 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,131 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,132 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 10")
# 2025-02-01 00:02:52,132 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,134 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 10")
# 2025-02-01 00:02:52,134 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,135 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 10
# 2025-02-01 00:02:52,136 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,178 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,254 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,257 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:52,257 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,262 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:52,263 INFO sqlalchemy.engine.Engine [generated in 0.00274s] [('1995', '10', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 463), ('1995', '10', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '10', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '10', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 844), ('1995', '10', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 630), ('1995', '10', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 457), ('1995', '10', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 339), ('1995', '10', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '10', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1995', '10', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:52,266 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,447 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,449 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 11")
# 2025-02-01 00:02:52,449 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,450 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 11")
# 2025-02-01 00:02:52,451 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,452 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 11
# 2025-02-01 00:02:52,453 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,492 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,572 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,574 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:52,575 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,580 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:52,580 INFO sqlalchemy.engine.Engine [generated in 0.00284s] [('1995', '11', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 463), ('1995', '11', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '11', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '11', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 845), ('1995', '11', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 629), ('1995', '11', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 456), ('1995', '11', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 338), ('1995', '11', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 516)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '11', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1995', '11', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 358)]
# 2025-02-01 00:02:52,583 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,765 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,766 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 12")
# 2025-02-01 00:02:52,766 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,767 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 12")
# 2025-02-01 00:02:52,768 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,769 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1995 AND month_code = 12
# 2025-02-01 00:02:52,770 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,812 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:52,888 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:52,890 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:52,891 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:52,895 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:52,896 INFO sqlalchemy.engine.Engine [generated in 0.00263s] [('1995', '12', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 463), ('1995', '12', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1118), ('1995', '12', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 657), ('1995', '12', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 844), ('1995', '12', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 629), ('1995', '12', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 456), ('1995', '12', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 338), ('1995', '12', 'Alabama', ' AL', '01', 'Tuscaloosa County', 'C125', '01125', 517)  ... displaying 10 of 459 total bound parameter sets ...  ('1995', '12', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1995', '12', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 356)]
# 2025-02-01 00:02:52,899 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,083 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,084 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 1")
# 2025-02-01 00:02:53,084 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,085 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 1")
# 2025-02-01 00:02:53,086 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,087 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 1
# 2025-02-01 00:02:53,088 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,128 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,207 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,210 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:53,210 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,215 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:53,216 INFO sqlalchemy.engine.Engine [generated in 0.00342s] [('1996', '1', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 439), ('1996', '1', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1054), ('1996', '1', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 620), ('1996', '1', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '1', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '1', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '1', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 304), ('1996', '1', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '1', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1996', '1', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 350)]
# 2025-02-01 00:02:53,220 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,409 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 2")
# 2025-02-01 00:02:53,410 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,411 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 2")
# 2025-02-01 00:02:53,412 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,413 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 2
# 2025-02-01 00:02:53,414 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,452 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,527 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,529 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:53,530 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,535 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:53,535 INFO sqlalchemy.engine.Engine [generated in 0.00267s] [('1996', '2', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 440), ('1996', '2', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1054), ('1996', '2', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 621), ('1996', '2', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '2', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '2', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '2', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '2', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '2', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1996', '2', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 349)]
# 2025-02-01 00:02:53,539 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,714 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,715 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 3")
# 2025-02-01 00:02:53,715 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,717 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 3")
# 2025-02-01 00:02:53,717 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,718 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 3
# 2025-02-01 00:02:53,719 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,759 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:53,838 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:53,840 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:53,841 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:53,846 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:53,847 INFO sqlalchemy.engine.Engine [generated in 0.00283s] [('1996', '3', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 439), ('1996', '3', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1054), ('1996', '3', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 621), ('1996', '3', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 824), ('1996', '3', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '3', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '3', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '3', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '3', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1996', '3', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 350)]
# 2025-02-01 00:02:53,851 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,048 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,049 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 4")
# 2025-02-01 00:02:54,049 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,050 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 4")
# 2025-02-01 00:02:54,051 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,052 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 4
# 2025-02-01 00:02:54,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,095 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,172 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:54,173 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,178 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:54,178 INFO sqlalchemy.engine.Engine [generated in 0.00271s] [('1996', '4', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 440), ('1996', '4', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1055), ('1996', '4', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 620), ('1996', '4', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '4', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '4', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 418), ('1996', '4', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '4', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '4', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1996', '4', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 348)]
# 2025-02-01 00:02:54,181 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,350 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 5")
# 2025-02-01 00:02:54,350 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,351 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 5")
# 2025-02-01 00:02:54,352 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,353 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 5
# 2025-02-01 00:02:54,354 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,392 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,466 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,468 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:54,469 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,474 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:54,474 INFO sqlalchemy.engine.Engine [generated in 0.00275s] [('1996', '5', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 440), ('1996', '5', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1054), ('1996', '5', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 621), ('1996', '5', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '5', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '5', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '5', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '5', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '5', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1996', '5', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 349)]
# 2025-02-01 00:02:54,477 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,659 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,660 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 6")
# 2025-02-01 00:02:54,660 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,662 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 6")
# 2025-02-01 00:02:54,662 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,663 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 6
# 2025-02-01 00:02:54,664 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,703 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,776 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,779 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:54,779 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,784 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:54,784 INFO sqlalchemy.engine.Engine [generated in 0.00246s] [('1996', '6', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 440), ('1996', '6', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1053), ('1996', '6', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 620), ('1996', '6', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 824), ('1996', '6', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '6', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 418), ('1996', '6', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '6', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '6', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1996', '6', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 349)]
# 2025-02-01 00:02:54,787 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:54,969 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:54,970 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 7")
# 2025-02-01 00:02:54,971 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,972 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 7")
# 2025-02-01 00:02:54,972 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:54,973 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 7
# 2025-02-01 00:02:54,974 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,014 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,091 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,093 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:55,094 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,098 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:55,099 INFO sqlalchemy.engine.Engine [generated in 0.00274s] [('1996', '7', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 439), ('1996', '7', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1053), ('1996', '7', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 620), ('1996', '7', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '7', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '7', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '7', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '7', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '7', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1996', '7', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 348)]
# 2025-02-01 00:02:55,102 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,285 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,286 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 8")
# 2025-02-01 00:02:55,287 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,288 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 8")
# 2025-02-01 00:02:55,289 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,289 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 8
# 2025-02-01 00:02:55,290 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,331 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,411 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,413 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:55,414 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,418 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:55,419 INFO sqlalchemy.engine.Engine [generated in 0.00317s] [('1996', '8', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 439), ('1996', '8', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1053), ('1996', '8', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 619), ('1996', '8', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 823), ('1996', '8', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '8', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '8', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 303), ('1996', '8', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '8', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 547), ('1996', '8', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 349)]
# 2025-02-01 00:02:55,423 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,603 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,604 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 9")
# 2025-02-01 00:02:55,605 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,606 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 9")
# 2025-02-01 00:02:55,607 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,607 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 9
# 2025-02-01 00:02:55,608 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,647 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,726 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,728 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:55,729 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,734 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:02:55,735 INFO sqlalchemy.engine.Engine [generated in 0.00283s] [('1996', '9', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 439), ('1996', '9', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 1053), ('1996', '9', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 619), ('1996', '9', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 822), ('1996', '9', 'Alabama', ' AL', '01', 'Montgomery County', 'C101', '01101', 597), ('1996', '9', 'Alabama', ' AL', '01', 'Morgan County', 'C103', '01103', 419), ('1996', '9', 'Alabama', ' AL', '01', 'St. Clair County', 'C115', '01115', 304), ('1996', '9', 'Alabama', ' AL', '01', 'Shelby County', 'C117', '01117', 303)  ... displaying 10 of 460 total bound parameter sets ...  ('1996', '9', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 548), ('1996', '9', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 348)]
# 2025-02-01 00:02:55,738 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:55,920 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:55,921 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 10")
# 2025-02-01 00:02:55,921 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,922 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 10")
# 2025-02-01 00:02:55,924 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,925 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 1996 AND month_code = 10
# 2025-02-01 00:02:55,926 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:55,964 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:02:56,036 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:02:56,039 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:02:56,039 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:02:56,044 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ...
# 2025-02-01 00:03:46,623 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:46,628 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:46,628 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 6")
# 2025-02-01 00:03:46,629 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,630 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 6")
# 2025-02-01 00:03:46,631 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,632 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 6
# 2025-02-01 00:03:46,632 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,671 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:46,752 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:46,754 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:46,755 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,761 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:46,762 INFO sqlalchemy.engine.Engine [generated in 0.00375s] [('2023', '6', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 339), ('2023', '6', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 256), ('2023', '6', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 251), ('2023', '6', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 267), ('2023', '6', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 821), ('2023', '6', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 337), ('2023', '6', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 560), ('2023', '6', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 572)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '6', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 444), ('2023', '6', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 268)]
# 2025-02-01 00:03:46,765 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:46,770 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:46,771 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 7")
# 2025-02-01 00:03:46,771 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,773 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 7")
# 2025-02-01 00:03:46,773 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,774 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 7
# 2025-02-01 00:03:46,775 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,824 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:46,906 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:46,909 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:46,909 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,914 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:46,915 INFO sqlalchemy.engine.Engine [generated in 0.00288s] [('2023', '7', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 351), ('2023', '7', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 276), ('2023', '7', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 274), ('2023', '7', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 269), ('2023', '7', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 863), ('2023', '7', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 329), ('2023', '7', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 518), ('2023', '7', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 608)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '7', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 401), ('2023', '7', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 271)]
# 2025-02-01 00:03:46,918 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:46,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:46,923 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 8")
# 2025-02-01 00:03:46,924 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,925 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 8")
# 2025-02-01 00:03:46,925 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,926 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 8
# 2025-02-01 00:03:46,927 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:46,966 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,048 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,050 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:47,051 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,057 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:47,057 INFO sqlalchemy.engine.Engine [generated in 0.00333s] [('2023', '8', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 399), ('2023', '8', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 269), ('2023', '8', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 282), ('2023', '8', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 299), ('2023', '8', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 869), ('2023', '8', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 347), ('2023', '8', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 579), ('2023', '8', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 610)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '8', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 461), ('2023', '8', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 272)]
# 2025-02-01 00:03:47,061 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,065 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,066 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 9")
# 2025-02-01 00:03:47,067 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,068 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 9")
# 2025-02-01 00:03:47,069 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,070 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 9
# 2025-02-01 00:03:47,070 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,110 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,194 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:47,194 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,200 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:47,200 INFO sqlalchemy.engine.Engine [generated in 0.00289s] [('2023', '9', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 377), ('2023', '9', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 299), ('2023', '9', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 255), ('2023', '9', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 256), ('2023', '9', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 838), ('2023', '9', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 337), ('2023', '9', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 571), ('2023', '9', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 604)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '9', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 437), ('2023', '9', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 255)]
# 2025-02-01 00:03:47,203 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,208 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,208 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 10")
# 2025-02-01 00:03:47,209 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,210 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 10")
# 2025-02-01 00:03:47,211 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,212 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 10
# 2025-02-01 00:03:47,213 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,252 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,328 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,331 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:47,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,337 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:47,338 INFO sqlalchemy.engine.Engine [generated in 0.00338s] [('2023', '10', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 386), ('2023', '10', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 264), ('2023', '10', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 245), ('2023', '10', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 268), ('2023', '10', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 809), ('2023', '10', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 339), ('2023', '10', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 585), ('2023', '10', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 618)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '10', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 433), ('2023', '10', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 254)]
# 2025-02-01 00:03:47,341 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,347 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 11")
# 2025-02-01 00:03:47,347 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,348 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 11")
# 2025-02-01 00:03:47,349 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,350 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 11
# 2025-02-01 00:03:47,351 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,389 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,475 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,477 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:47,478 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,483 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:47,484 INFO sqlalchemy.engine.Engine [generated in 0.00330s] [('2023', '11', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 368), ('2023', '11', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 275), ('2023', '11', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 273), ('2023', '11', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 293), ('2023', '11', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 778), ('2023', '11', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 351), ('2023', '11', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 532), ('2023', '11', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 578)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '11', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 385), ('2023', '11', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 236)]
# 2025-02-01 00:03:47,488 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,493 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 12")
# 2025-02-01 00:03:47,494 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,495 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 12")
# 2025-02-01 00:03:47,495 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,496 INFO sqlalchemy.engine.Engine SELECT * FROM cdc_data WHERE year_code = 2023 AND month_code = 12
# 2025-02-01 00:03:47,497 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,536 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-01 00:03:47,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:03:47,623 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("processed_cdc_data")
# 2025-02-01 00:03:47,623 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:03:47,629 INFO sqlalchemy.engine.Engine INSERT INTO processed_cdc_data (year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-02-01 00:03:47,629 INFO sqlalchemy.engine.Engine [generated in 0.00321s] [('2023', '12', 'Alabama', ' AL', '01', 'Baldwin County', 'C003', '01003', 380), ('2023', '12', 'Alabama', ' AL', '01', 'Calhoun County', 'C015', '01015', 259), ('2023', '12', 'Alabama', ' AL', '01', 'Etowah County', 'C055', '01055', 259), ('2023', '12', 'Alabama', ' AL', '01', 'Houston County', 'C069', '01069', 272), ('2023', '12', 'Alabama', ' AL', '01', 'Jefferson County', 'C073', '01073', 793), ('2023', '12', 'Alabama', ' AL', '01', 'Lee County', 'C081', '01081', 321), ('2023', '12', 'Alabama', ' AL', '01', 'Madison County', 'C089', '01089', 544), ('2023', '12', 'Alabama', ' AL', '01', 'Mobile County', 'C097', '01097', 585)  ... displaying 10 of 580 total bound parameter sets ...  ('2023', '12', 'Wisconsin', ' WI', '55', 'Waukesha County', 'C133', '55133', 386), ('2023', '12', 'Wisconsin', ' WI', '55', 'Winnebago County', 'C139', '55139', 242)]
# 2025-02-01 00:03:47,633 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Archiving the old data from the cleaned data directory to be replaced with this new data.

# %%
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 


set_search_pattern = "cdc_data_main_df*"
set_search_folder = "cleaned_cdc_data"
set_save_folder = "archived_cdc_data"
set_save_file = "CDC_Cleaned_Data_Unspecified_Counties_Removed"
filter_extension = False
filter_by_file_extension = None
archive_module.create_archive(set_search_pattern, set_search_folder, set_save_folder, set_save_file, filter_extension, filter_by_file_extension, delete=True)


#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 
#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### ####
# Out:
# Files archived successfully.
# Deleted: D:\WGU\New folder\D497\WGU_D497_Project_1\data\cleaned_data\cdc_data\cdc_data_main_df.csv
# Deleted: D:\WGU\New folder\D497\WGU_D497_Project_1\data\cleaned_data\cdc_data\cdc_data_main_df.pkl
# WGU/New folder/D497/WGU_D497_Project_1/data/cleaned_data/cdc_data/cdc_data_main_df.csv
# 	Modified:	2025-01-31 23:59:20
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	11392702 bytes
# 	Uncompressed:	11392702 bytes
# WGU/New folder/D497/WGU_D497_Project_1/data/cleaned_data/cdc_data/cdc_data_main_df.pkl
# 	Modified:	2025-01-31 23:59:20
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	15429101 bytes
# 	Uncompressed:	15429101 bytes

# %%
# Creating new empty dataframe
cdc_data_main_df = pd.DataFrame()

# %%
# Pulling data from the newly created table

sql_query = """
SELECT * FROM processed_cdc_data
"""

# %%
# Creating new dataframe from the pulled data using the database helper tool.

cdc_data_main_df = db_tool.export_df_from_sql(sql_query, cdc_data_main_df)
# Out:
# 2025-02-01 00:10:57,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-01 00:10:57,534 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("
# SELECT * FROM processed_cdc_data
# ")
# 2025-02-01 00:10:57,535 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:10:57,537 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("
# SELECT * FROM processed_cdc_data
# ")
# 2025-02-01 00:10:57,538 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:10:57,539 INFO sqlalchemy.engine.Engine
# SELECT * FROM processed_cdc_data
#
# 2025-02-01 00:10:57,540 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-01 00:10:58,338 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Getting info
cdc_data_main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187620 entries, 0 to 187619
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year_code       187620 non-null  object
#  1   month_code      187620 non-null  object
#  2   state           187620 non-null  object
#  3   state_code      187620 non-null  object
#  4   state_fipcode   187620 non-null  object
#  5   county          187620 non-null  object
#  6   county_fipcode  187620 non-null  object
#  7   fips_five       187620 non-null  object
#  8   births          187620 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 12.9+ MB

# %%
# Visual Inspection
cdc_data_main_df.head()
# Out:
#   year_code month_code    state state_code state_fipcode             county  \
# 0      1995          1  Alabama         AL            01     Calhoun County
# 1      1995          1  Alabama         AL            01   Jefferson County
# 2      1995          1  Alabama         AL            01     Madison County
# 3      1995          1  Alabama         AL            01      Mobile County
# 4      1995          1  Alabama         AL            01  Montgomery County
#
#   county_fipcode fips_five  births
# 0           C015     01015     464
# 1           C073     01073    1118
# 2           C089     01089     658
# 3           C097     01097     845
# 4           C101     01101     631

# %%
# Another Visual Inspection 
cdc_data_main_df.sample(10)
# Out:
#        year_code month_code       state state_code state_fipcode  \
# 37375       2001         10    Illinois         IL            17
# 36792       2001          9     Alabama         AL            01
# 35738       2001          6    Oklahoma         OK            40
# 137898      2016         11    Illinois         IL            17
# 72826       2007          7  California         CA            06
# 118013      2013         12   Wisconsin         WI            55
# 166489      2020         12    New York         NY            36
# 48947       2003         10     Florida         FL            12
# 92410       2010          4       Texas         TX            48
# 78386       2008          4        Ohio         OH            39
#
#                    county county_fipcode fips_five  births
# 37375     Sangamon County           C167     17167     350
# 36792   Montgomery County           C101     01101     592
# 35738     Comanche County           C031     40031     684
# 137898     LaSalle County           C099     17099     190
# 72826   Sacramento County           C067     06067    2018
# 118013      Racine County           C101     55101     325
# 166489       Bronx County           C005     36005    1372
# 48947          Bay County           C005     12005     218
# 92410        Bexar County           C029     48029    2146
# 78386       Butler County           C017     39017     534

# %%
# Checking for unspecified counties 
cdc_data_main_df[cdc_data_main_df['county_fipcode'] == "C999"]
# Out:
# Empty DataFrame
# Columns: [year_code, month_code, state, state_code, state_fipcode, county, county_fipcode, fips_five, births]
# Index: []

# %%
# Creating a new cleaned data file for the cdc data in the data directory
CheckPoint.create_checkpoint("cleaned_cdc_data", "cdc_data_main_df", cdc_data_main_df)

# %% [markdown]
# ## [Next Step: Data Cleaning - UFO](data_cleaning_ufo_main.ipynb)
# ---
# #### [Return To Landing Page](order_of_operations_landing.ipynb)
