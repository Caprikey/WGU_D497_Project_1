# %%
# Data Cleaning - Zip Module
### Version 1
#### 12/31/24
#### 17:00

# %%
# Zipfile
import zipfile

# RegularExpression for string matching
import re

# GLOB 
import glob 

# Pathlib 
from pathlib import Path

# NB Importer
import nbimporter

# Date Time
import datetime 

# My Modules

## Folder Manager
import folder_manager as fm

## Database Helper
import database_helper as db_tool

# %%
global raw_data_base_folder_path

global raw_ufo_data_folder_path
global raw_cdc_natality_data_folder_path
global raw_fips_data_folder_path

global doc_folder_path

global cleaned_data_base_folder_path

global cleaned_ufo_data_folder_path
global cleaned_cdc_natality_data_folder_path
global cleaned_fips_data_folder_path

global archived_data_folder_path 

global files_downloads_folder_path

#global archive_dictionary = {}
archive_dictionary = {}

#global matched_files = []
matched_files = []

global search_pattern
global search_folder
global save_folder
global save_file

global archive_file_path

global delete_flag
global filter_extension_flag
global file_extension_filter

# %%
def setup_working_directories():

    global base_data_folder_path

    global doc_folder_path
    global archived_data_folder_path
    
    global raw_data_base_folder_path
    global raw_ufo_data_folder_path
    global raw_cdc_natality_data_folder_path
    global raw_fips_data_folder_path

    global cleaned_data_base_folder_path
    global cleaned_ufo_data_folder_path
    global cleaned_cdc_natality_data_folder_path
    global cleaned_fips_data_folder_path

    #### #### #### ####
    
    fm.initialize_folder_paths()

    ####

    doc_folder_path = fm.get_folder_path("raw_FIPS_Data")
    
    ####
    
    base_data_folder_path = fm.get_folder_path("data_folder")

    ####

    files_downloads_folder_path = fm.get_folder_path("files_downloads")
    
    #### 
    
    raw_data_base_folder_path = fm.get_folder_path("raw_files")
    
    raw_ufo_data_folder_path = fm.get_folder_path("raw_UFO_Data")
    
    raw_cdc_natality_data_folder_path = fm.get_folder_path("raw_CDC_Natality_Birth_Data")
    
    raw_fips_data_folder_path = fm.get_folder_path("raw_FIPS_Data")

    ####
    
    cleaned_data_base_folder_path = fm.get_folder_path("cleaned_data")
    
    cleaned_ufo_data_folder_path = fm.get_folder_path("cleaned_UFO_Data")

    cleaned_cdc_natality_data_folder_path = fm.get_folder_path("cleaned_CDC_Natality_Birth_Data")

    cleaned_fips_data_folder_path = fm.get_folder_path(" cleaned_FIPS_Data")

    ####

    archived_data_folder_path = fm.get_folder_path("archived_data_folder")

# %%
def find_matched_files(path, pattern, filter_extension_flag=False, file_extension_filter=None):

    search_folder_path = path
    
    search_file_name_pattern_base = pattern

    if filter_extension_flag:
        
        if not file_extension_filter:
            raise ValueError("Extension is required when extension flag is set to True")
        

        normalized_file_extension = f".{file_extension_filter.lstrip('.')}"

        
#         if not path.endswith(normalized_extension):
#             raise ValueError(
#                 f"file_path must end with the specified extension: {normalized_extension}"
#             )  

        search_file_name_pattern_full = search_file_name_pattern_base + "*" + normalized_file_extension

    
    else:

        search_file_name_pattern_full = search_file_name_pattern_base + "*"



    matched_files = glob.glob(search_folder_path + "/" + search_file_name_pattern_full)


    if matched_files:
        matched_files.sort()
        #print(matched_files)
        return matched_files

    else:
        print(f"No Files Found That Match the File Name Pattern {search_file_name_pattern_full} in {search_folder_path}")

# %%
def archive_files(matched_files, archive_name, destination_folder):

    global archive_file_path
    
    if destination_folder == "default":
        destination_save_folder = archived_data_folder_path
    else:
        destination_save_folder = destination_folder
    
    archive_file_name = archive_name + ".zip"

    archive_file_path = destination_save_folder + "/" + archive_file_name
    
    try:
        with zipfile.ZipFile(archive_file_path, 'w') as archive_zip:
                
            for file_path in matched_files:
                    
                file = Path(file_path)
                
                if file.exists():
                    archive_zip.write(file_path, arcname=file_path)
                else:
                    print(f"File not found: {file_path}")
        return True
        
    except Exception as e:
        print(f"Error archiving files: {e}")
        return False


   # with zipfile.ZipFile("directory.zip", mode="r") as archive:
        #archive.printdir()

# %%
def delete_files(files_to_delete):
    """
    Deletes the given files.

    Args:
        files_to_delete (list): List of file paths to delete.
    """
    for file_path in files_to_delete:
        try:
            file = Path(file_path)
            if file.exists():
                file.unlink()  # Deletes the file
                print(f"Deleted: {file_path}")
            else:
                print(f"File not found, cannot delete: {file_path}")
        except Exception as e:
            print(f"Error deleting file {file_path}: {e}")

# %%
def get_archive_details(file_path):

    """
    Prints details of the contents of a zip file.

    Args:
        file_path (str): Path to the zip file.
    """
    # Opening the zip file in READ mode
    
    with zipfile.ZipFile(file_path, 'r') as zip:
        for info in zip.infolist(): 
                print(info.filename) 
                print('\tModified:\t' + str(datetime.datetime(*info.date_time))) 
                print('\tSystem:\t\t' + str(info.create_system) + '(0 = Windows, 3 = Unix)') 
                print('\tZIP version:\t' + str(info.create_version)) 
                print('\tCompressed:\t' + str(info.compress_size) + ' bytes') 
                print('\tUncompressed:\t' + str(info.file_size) + ' bytes')

# %%
def main():

    # Initializer Commands

    # Initializes Folder Manager Requirements
    fm.initialize_folder_paths()
    
    # Initializes Database Engine and Session For SQL
    #db_tool.initialize_engine()
    #db_tool.initialize_session()
    
    # Initializes The Folders for This Notebook
    setup_working_directories()
    
    global search_pattern
    global search_folder 
    global save_folder
    global save_file

    global delete_flag 
    global filter_extension_flag
    global file_extension_filter 

    if filter_extension_flag:
         
        if not file_extension_filter:
            
            raise ValueError("extension is required when filter_extension_flag is True.")


    get_search_folder_path = fm.get_folder_path(search_folder)
    get_save_folder_path = fm.get_folder_path(save_folder)
    
    matched_files = find_matched_files(get_search_folder_path, search_pattern, filter_extension_flag, file_extension_filter)
    
    if archive_files(matched_files, save_file, get_save_folder_path):
        print("Files archived successfully.")
        # Delete the original files
        if delete_flag:
            delete_files(matched_files)
    else:
        print("Archiving failed. Files not deleted.")

    results = get_archive_details(archive_file_path)

# %%
def create_archive(set_search_pattern, set_search_folder, set_save_folder, set_save_file, filter_extension=False, filter_by_file_extension=None, delete=True):

    # Initializer Commands

    # Initializes Folder Manager Requirements
    fm.initialize_folder_paths()
    
    # Initializes Database Engine and Session For SQL
    #db_tool.initialize_engine()
    #db_tool.initialize_session()
    
    # Initializes The Folders for This Notebook
    setup_working_directories()
    
    global search_pattern
    global search_folder 
    global save_folder
    global save_file
    global delete_flag
    global filter_extension_flag
    global file_extension_filter

    search_pattern = set_search_pattern
    search_folder = set_search_folder
    save_folder = set_save_folder
    save_file = set_save_file
    filter_extension_flag = filter_extension
    file_extension_filter = filter_by_file_extension
    delete_flag = delete

    main()

# %%
fm.initialize_folder_paths()
find_matched_files(fm.get_folder_path("raw_CDC_Natality_Birth_Data"), "Raw_CDC_Natality_Birth_Data", filter_extension_flag=True, file_extension_filter=".txt")
# Out:
# ['D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_1995.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_1996.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_1997.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_1998.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_1999.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2000.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2001.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2002.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2003.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2004.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2005.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2006.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2007.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2008.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2009.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2010.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2011.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2012.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2013.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2014.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2015.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2016.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2017.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2018.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2019.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2020.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2021.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2022.txt',
#  'D:\\WGU\\D497\\Project_1-Real_World_Data_Wrangling_With_Python\\data\\file_downloads\\raw_files\\CDC_Natality_Birth_Data\\Raw_CDC_Natality_Birth_Data_2023.txt']

# %%
if __name__ == "__main__":
    
    # Initializer Commands

    # Initializes Folder Manager Requirements
    fm.initialize_folder_paths()
    
    # Initializes Database Engine and Session For SQL
    #db_tool.initialize_engine()
    #db_tool.initialize_session()
    
    # Initializes The Folders for This Notebook
    setup_working_directories()
    
    search_pattern = "ufo_data_main_"
    search_folder = raw_ufo_data_folder_path
    save_folder = archived_data_folder_path
    save_file = "ufo_data_main_data_cleaning_backups_test_2"
    filter_extension_flag = False
    file_extension_filter = ".pkl"
    delete_flag = False
    
    main()
# Out:
# Files archived successfully.
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_five_matched.csv
# 	Modified:	2024-12-31 04:01:18
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	513657 bytes
# 	Uncompressed:	513657 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_five_matched.pkl
# 	Modified:	2024-12-31 04:01:18
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	744872 bytes
# 	Uncompressed:	744872 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_five_unknown_labled_non_matched.csv
# 	Modified:	2024-12-30 02:16:44
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	16060 bytes
# 	Uncompressed:	16060 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_five_unknown_labled_non_matched.pkl
# 	Modified:	2024-12-30 02:16:44
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	32904 bytes
# 	Uncompressed:	32904 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_four_matched.csv
# 	Modified:	2024-12-30 02:08:38
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	513657 bytes
# 	Uncompressed:	513657 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_four_matched.pkl
# 	Modified:	2024-12-30 02:08:38
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	744872 bytes
# 	Uncompressed:	744872 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_four_non_matched.csv
# 	Modified:	2024-12-30 02:08:36
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	16060 bytes
# 	Uncompressed:	16060 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_four_non_matched.pkl
# 	Modified:	2024-12-30 02:08:36
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	32904 bytes
# 	Uncompressed:	32904 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_duplicates.csv
# 	Modified:	2024-12-30 01:26:58
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	1091566 bytes
# 	Uncompressed:	1091566 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_duplicates.pkl
# 	Modified:	2024-12-30 01:26:58
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	1043528 bytes
# 	Uncompressed:	1043528 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_duplicates_filtered.csv
# 	Modified:	2024-12-30 01:27:08
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	7576649 bytes
# 	Uncompressed:	7576649 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_duplicates_filtered.pkl
# 	Modified:	2024-12-30 01:27:08
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	8321209 bytes
# 	Uncompressed:	8321209 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_non_matched_non_null.csv
# 	Modified:	2024-12-30 01:27:50
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	620134 bytes
# 	Uncompressed:	620134 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_non_matched_non_null.pkl
# 	Modified:	2024-12-30 01:27:50
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	1161443 bytes
# 	Uncompressed:	1161443 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_non_matched_null.csv
# 	Modified:	2024-12-30 01:27:54
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	12339 bytes
# 	Uncompressed:	12339 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_one_non_matched_null.pkl
# 	Modified:	2024-12-30 01:27:54
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	30293 bytes
# 	Uncompressed:	30293 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_three_matched.csv
# 	Modified:	2024-12-30 02:16:46
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	513657 bytes
# 	Uncompressed:	513657 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_three_matched.pkl
# 	Modified:	2024-12-30 02:16:46
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	744872 bytes
# 	Uncompressed:	744872 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_three_non_matched.csv
# 	Modified:	2024-12-30 02:08:48
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	16060 bytes
# 	Uncompressed:	16060 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_three_non_matched.pkl
# 	Modified:	2024-12-30 02:08:48
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	32904 bytes
# 	Uncompressed:	32904 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_two_matched.csv
# 	Modified:	2024-12-30 01:31:44
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	195187 bytes
# 	Uncompressed:	195187 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_two_matched.pkl
# 	Modified:	2024-12-30 01:31:44
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	297783 bytes
# 	Uncompressed:	297783 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_two_non_matched.csv
# 	Modified:	2024-12-30 01:31:38
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	455904 bytes
# 	Uncompressed:	455904 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merge_pass_two_non_matched.pkl
# 	Modified:	2024-12-30 01:31:38
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	840212 bytes
# 	Uncompressed:	840212 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merged_pass_one_matched.csv
# 	Modified:	2024-12-30 01:27:52
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	6944410 bytes
# 	Uncompressed:	6944410 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_merged_pass_one_matched.pkl
# 	Modified:	2024-12-30 01:27:52
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	7132038 bytes
# 	Uncompressed:	7132038 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_mv_filtered.csv
# 	Modified:	2024-12-29 19:07:24
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	3617563 bytes
# 	Uncompressed:	3617563 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_mv_filtered.pkl
# 	Modified:	2024-12-29 19:07:24
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	4870343 bytes
# 	Uncompressed:	4870343 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_mv_needed.csv
# 	Modified:	2024-12-29 19:05:42
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	240547 bytes
# 	Uncompressed:	240547 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_mv_needed.pkl
# 	Modified:	2024-12-29 19:05:42
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	293153 bytes
# 	Uncompressed:	293153 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_special_characters_checkpoint_1.csv
# 	Modified:	2024-12-29 18:56:32
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	275409 bytes
# 	Uncompressed:	275409 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_special_characters_checkpoint_1.pkl
# 	Modified:	2024-12-29 18:56:32
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	336315 bytes
# 	Uncompressed:	336315 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_special_characters_checkpoint_2.csv
# 	Modified:	2024-12-29 19:05:16
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	240547 bytes
# 	Uncompressed:	240547 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_cities_special_characters_checkpoint_2.pkl
# 	Modified:	2024-12-29 19:05:16
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	293153 bytes
# 	Uncompressed:	293153 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_date_cleaned.csv
# 	Modified:	2024-12-29 16:05:06
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	7652078 bytes
# 	Uncompressed:	7652078 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_date_structured.csv
# 	Modified:	2024-12-29 16:10:46
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	3876231 bytes
# 	Uncompressed:	3876231 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_date_structured.pkl
# 	Modified:	2024-12-29 16:10:46
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	4458548 bytes
# 	Uncompressed:	4458548 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_dropped.csv
# 	Modified:	2024-12-29 16:03:30
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	22978090 bytes
# 	Uncompressed:	22978090 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_international_sightings.csv
# 	Modified:	2024-12-29 16:09:28
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	1141971 bytes
# 	Uncompressed:	1141971 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_kept.csv
# 	Modified:	2024-12-29 15:34:08
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	10074854 bytes
# 	Uncompressed:	10074854 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_state_manual_verification_needed.csv
# 	Modified:	2024-12-29 16:37:06
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	2434 bytes
# 	Uncompressed:	2434 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_state_manual_verification_needed.pkl
# 	Modified:	2024-12-29 16:37:06
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	4621 bytes
# 	Uncompressed:	4621 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_state_mv_filtered_removed.csv
# 	Modified:	2024-12-29 16:40:20
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	3863338 bytes
# 	Uncompressed:	3863338 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_state_mv_filtered_removed.pkl
# 	Modified:	2024-12-29 16:40:20
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	4461855 bytes
# 	Uncompressed:	4461855 bytes
# WGU/D497/Project_1-Real_World_Data_Wrangling_With_Python/data/file_downloads/raw_files/UFO_Data/ufo_data_main_usa_sightings.csv
# 	Modified:	2024-12-29 16:09:32
# 	System:		0(0 = Windows, 3 = Unix)
# 	ZIP version:	20
# 	Compressed:	7317752 bytes
# 	Uncompressed:	7317752 bytes
